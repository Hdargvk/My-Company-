# %%
import pandas as pd

# %%
_df=pd.read_csv(r"D:\New folder\italy-covid-daywise.csv")

# %%
_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
_df.info
# Out:
# <bound method DataFrame.info of            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]>

# %%
_df.shape
# Out:
# (248, 4)

# %%
_df.describe()
# Out:
#          new_cases  new_deaths     new_tests
# count   248.000000  248.000000    135.000000
# mean   1094.818548  143.133065  31699.674074
# std    1554.508002  227.105538  11622.209757
# min    -148.000000  -31.000000   7841.000000
# 25%     123.000000    3.000000  25259.000000
# 50%     342.000000   17.000000  29545.000000
# 75%    1371.750000  175.250000  37711.000000
# max    6557.000000  971.000000  95273.000000

# %%
_df.columns
# Out:
# Index(['date', 'new_cases', 'new_deaths', 'new_tests'], dtype='object')

# %%
cases_df=_df[['date','new_cases']]

# %%
cases_df
# Out:
#            date  new_cases
# 0    2019-12-31        0.0
# 1    2020-01-01        0.0
# 2    2020-01-02        0.0
# 3    2020-01-03        0.0
# 4    2020-01-04        0.0
# ..          ...        ...
# 243  2020-08-30     1444.0
# 244  2020-08-31     1365.0
# 245  2020-09-01      996.0
# 246  2020-09-02      975.0
# 247  2020-09-03     1326.0
#
# [248 rows x 2 columns]

# %%
high_new_cases = _df.new_cases>1000

# %%
high_new_cases
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 243     True
# 244     True
# 245    False
# 246    False
# 247     True
# Name: new_cases, Length: 248, dtype: bool

# %%
_df[high_new_cases]
# Out:
#            date  new_cases  new_deaths  new_tests
# 68   2020-03-08     1247.0        36.0        NaN
# 69   2020-03-09     1492.0       133.0        NaN
# 70   2020-03-10     1797.0        98.0        NaN
# 72   2020-03-12     2313.0       196.0        NaN
# 73   2020-03-13     2651.0       189.0        NaN
# ..          ...        ...         ...        ...
# 241  2020-08-28     1409.0         5.0    65135.0
# 242  2020-08-29     1460.0         9.0    64294.0
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 247  2020-09-03     1326.0         6.0        NaN
#
# [72 rows x 4 columns]

# %%
high_cases_df=_df[_df.new_cases>1000]

# %%
high_cases_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 68   2020-03-08     1247.0        36.0        NaN
# 69   2020-03-09     1492.0       133.0        NaN
# 70   2020-03-10     1797.0        98.0        NaN
# 72   2020-03-12     2313.0       196.0        NaN
# 73   2020-03-13     2651.0       189.0        NaN
# ..          ...        ...         ...        ...
# 241  2020-08-28     1409.0         5.0    65135.0
# 242  2020-08-29     1460.0         9.0    64294.0
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 247  2020-09-03     1326.0         6.0        NaN
#
# [72 rows x 4 columns]

# %%
_df.new_cases/ _df.new_cases
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 243    1.0
# 244    1.0
# 245    1.0
# 246    1.0
# 247    1.0
# Name: new_cases, Length: 248, dtype: float64

# %%
_df['positive_rate']= _df.new_cases/ _df.new_tests

# %%
_df
# Out:
#            date  new_cases  new_deaths  new_tests  positive_rate
# 0    2019-12-31        0.0         0.0        NaN            NaN
# 1    2020-01-01        0.0         0.0        NaN            NaN
# 2    2020-01-02        0.0         0.0        NaN            NaN
# 3    2020-01-03        0.0         0.0        NaN            NaN
# 4    2020-01-04        0.0         0.0        NaN            NaN
# ..          ...        ...         ...        ...            ...
# 243  2020-08-30     1444.0         1.0    53541.0       0.026970
# 244  2020-08-31     1365.0         4.0    42583.0       0.032055
# 245  2020-09-01      996.0         6.0    54395.0       0.018311
# 246  2020-09-02      975.0         8.0        NaN            NaN
# 247  2020-09-03     1326.0         6.0        NaN            NaN
#
# [248 rows x 5 columns]

# %% [markdown]
# # Querying & Sorting Rows

# %%
_df.drop(columns=['positive_rate'], inplace=True)

# %%
_df.drop
# Out:
# <bound method DataFrame.drop of            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]>

# %%
_df.sort_values('new_cases',ascending=False).head(10)
# Out:
#           date  new_cases  new_deaths  new_tests
# 82  2020-03-22     6557.0       795.0        NaN
# 87  2020-03-27     6153.0       660.0        NaN
# 81  2020-03-21     5986.0       625.0        NaN
# 89  2020-03-29     5974.0       887.0        NaN
# 88  2020-03-28     5959.0       971.0        NaN
# 83  2020-03-23     5560.0       649.0        NaN
# 80  2020-03-20     5322.0       429.0        NaN
# 85  2020-03-25     5249.0       743.0        NaN
# 90  2020-03-30     5217.0       758.0        NaN
# 86  2020-03-26     5210.0       685.0        NaN

# %%
_df.sort_values('new_cases').head(10)
# Out:
#            date  new_cases  new_deaths  new_tests
# 172  2020-06-20     -148.0        47.0    29875.0
# 0    2019-12-31        0.0         0.0        NaN
# 29   2020-01-29        0.0         0.0        NaN
# 30   2020-01-30        0.0         0.0        NaN
# 32   2020-02-01        0.0         0.0        NaN
# 33   2020-02-02        0.0         0.0        NaN
# 34   2020-02-03        0.0         0.0        NaN
# 36   2020-02-05        0.0         0.0        NaN
# 37   2020-02-06        0.0         0.0        NaN
# 38   2020-02-07        0.0         0.0        NaN

# %%
_df.loc[170:175]
# Out:
#            date  new_cases  new_deaths  new_tests
# 170  2020-06-18      328.0        43.0    32921.0
# 171  2020-06-19      331.0        66.0    28570.0
# 172  2020-06-20     -148.0        47.0    29875.0
# 173  2020-06-21      264.0        49.0    24581.0
# 174  2020-06-22      224.0        24.0    16152.0
# 175  2020-06-23      221.0        23.0    23225.0

# %%
_df.at[172,'new_cases']=(_df.at[171,'new_cases']+_df.at[172,'new_cases']/2)

# %%
_df.loc[169:175]
# Out:
#            date  new_cases  new_deaths  new_tests
# 169  2020-06-17      210.0        34.0    33957.0
# 170  2020-06-18      328.0        43.0    32921.0
# 171  2020-06-19      331.0        66.0    28570.0
# 172  2020-06-20      257.0        47.0    29875.0
# 173  2020-06-21      264.0        49.0    24581.0
# 174  2020-06-22      224.0        24.0    16152.0
# 175  2020-06-23      221.0        23.0    23225.0

# %% [markdown]
# # Work On Date & Time

# %%
_df.date
# Out:
# 0      2019-12-31
# 1      2020-01-01
# 2      2020-01-02
# 3      2020-01-03
# 4      2020-01-04
#           ...
# 243    2020-08-30
# 244    2020-08-31
# 245    2020-09-01
# 246    2020-09-02
# 247    2020-09-03
# Name: date, Length: 248, dtype: object

# %%
_df['date']=pd.to_datetime(_df.date)

# %%
_df.date
# Out:
# 0     2019-12-31
# 1     2020-01-01
# 2     2020-01-02
# 3     2020-01-03
# 4     2020-01-04
#          ...
# 243   2020-08-30
# 244   2020-08-31
# 245   2020-09-01
# 246   2020-09-02
# 247   2020-09-03
# Name: date, Length: 248, dtype: datetime64[ns]

# %%
_df['year']= pd.DatetimeIndex(_df.date).year
_df['month']= pd.DatetimeIndex(_df.date).month
_df['day']= pd.DatetimeIndex(_df.date).day
_df['weekday']= pd.DatetimeIndex(_df.date).weekday

# %%
_df
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day  weekday
# 0   2019-12-31        0.0         0.0        NaN  2019     12   31        1
# 1   2020-01-01        0.0         0.0        NaN  2020      1    1        2
# 2   2020-01-02        0.0         0.0        NaN  2020      1    2        3
# 3   2020-01-03        0.0         0.0        NaN  2020      1    3        4
# 4   2020-01-04        0.0         0.0        NaN  2020      1    4        5
# ..         ...        ...         ...        ...   ...    ...  ...      ...
# 243 2020-08-30     1444.0         1.0    53541.0  2020      8   30        6
# 244 2020-08-31     1365.0         4.0    42583.0  2020      8   31        0
# 245 2020-09-01      996.0         6.0    54395.0  2020      9    1        1
# 246 2020-09-02      975.0         8.0        NaN  2020      9    2        2
# 247 2020-09-03     1326.0         6.0        NaN  2020      9    3        3
#
# [248 rows x 8 columns]

# %%
_df_may=_df[_df.month==5]
_df_may_metrics=_df_may[['new_cases','new_deaths','new_tests']]
_df_may_total=_df_may_metrics.sum()

# %%
_df_may_total
# Out:
# new_cases       29073.0
# new_deaths       5658.0
# new_tests     1078720.0
# dtype: float64

# %%
df_may=_df[_df.month==5]

# %%
_df_may_metrics=-df_may[['new_cases','new_deaths','new_tests']]

# %%
_df_may_total=_df_may_metrics.sum()

# %%
_df_may_total
# Out:
# new_cases      -29073.0
# new_deaths      -5658.0
# new_tests    -1078720.0
# dtype: float64

# %% [markdown]
# mean method

# %%
#USE TO FIND AVERAGE CASES
_df.new_cases.mean()
# Out:
# 1096.4516129032259

# %%
# AVRAGE FOR SUNDAY
_df[_df.weekday==6].new_cases.mean()
# Out:
# 1247.2571428571428

# %% [markdown]
# # Grouping And aggregation

# %%
_df
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day  weekday
# 0   2019-12-31        0.0         0.0        NaN  2019     12   31        1
# 1   2020-01-01        0.0         0.0        NaN  2020      1    1        2
# 2   2020-01-02        0.0         0.0        NaN  2020      1    2        3
# 3   2020-01-03        0.0         0.0        NaN  2020      1    3        4
# 4   2020-01-04        0.0         0.0        NaN  2020      1    4        5
# ..         ...        ...         ...        ...   ...    ...  ...      ...
# 243 2020-08-30     1444.0         1.0    53541.0  2020      8   30        6
# 244 2020-08-31     1365.0         4.0    42583.0  2020      8   31        0
# 245 2020-09-01      996.0         6.0    54395.0  2020      9    1        1
# 246 2020-09-02      975.0         8.0        NaN  2020      9    2        2
# 247 2020-09-03     1326.0         6.0        NaN  2020      9    3        3
#
# [248 rows x 8 columns]

# %%
_month_df= _df.groupby('month')[['new_cases','new_deaths','new_tests']].sum()

# %%
_month_df
# Out:
#        new_cases  new_deaths  new_tests
# month
# 1            3.0         0.0        0.0
# 2          885.0        21.0        0.0
# 3       100851.0     11570.0        0.0
# 4       101852.0     16091.0   419591.0
# 5        29073.0      5658.0  1078720.0
# 6         8177.0      1404.0   830354.0
# 7         6722.0       388.0   797692.0
# 8        21060.0       345.0  1098704.0
# 9         3297.0        20.0    54395.0
# 12           0.0         0.0        0.0

# %%
_month_df.loc[6]
# Out:
# new_cases       8177.0
# new_deaths      1404.0
# new_tests     830354.0
# Name: 6, dtype: float64

# %%
year_df= _df.groupby('year')[['new_cases','new_deaths','new_tests']].sum()

# %%
year_df
# Out:
#       new_cases  new_deaths  new_tests
# year
# 2019        0.0         0.0        0.0
# 2020   271920.0     35497.0  4279456.0

# %%
_df['total_cases']=_df.new_cases.cumsum()

# %%
_df['total_deaths']=_df.new_deaths.cumsum()

# %%
_df['total_tests']=_df.new_tests.cumsum()

# %%
_df
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day  weekday
# 0   2019-12-31        0.0         0.0        NaN  2019     12   31        1  \
# 1   2020-01-01        0.0         0.0        NaN  2020      1    1        2
# 2   2020-01-02        0.0         0.0        NaN  2020      1    2        3
# 3   2020-01-03        0.0         0.0        NaN  2020      1    3        4
# 4   2020-01-04        0.0         0.0        NaN  2020      1    4        5
# ..         ...        ...         ...        ...   ...    ...  ...      ...
# 243 2020-08-30     1444.0         1.0    53541.0  2020      8   30        6
# 244 2020-08-31     1365.0         4.0    42583.0  2020      8   31        0
# 245 2020-09-01      996.0         6.0    54395.0  2020      9    1        1
# 246 2020-09-02      975.0         8.0        NaN  2020      9    2        2
# 247 2020-09-03     1326.0         6.0        NaN  2020      9    3        3
#
#      total_cases  total_deaths  total_tests
# ...

# %% [markdown]
# # Writing data back to files

# %%
result_df= _df[['date','new_cases','new_deaths','new_tests','year','month','day','weekday','total_cases','total_deaths','total_tests']]

# %%
result_df
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day  weekday
# 0   2019-12-31        0.0         0.0        NaN  2019     12   31        1  \
# 1   2020-01-01        0.0         0.0        NaN  2020      1    1        2
# 2   2020-01-02        0.0         0.0        NaN  2020      1    2        3
# 3   2020-01-03        0.0         0.0        NaN  2020      1    3        4
# 4   2020-01-04        0.0         0.0        NaN  2020      1    4        5
# ..         ...        ...         ...        ...   ...    ...  ...      ...
# 243 2020-08-30     1444.0         1.0    53541.0  2020      8   30        6
# 244 2020-08-31     1365.0         4.0    42583.0  2020      8   31        0
# 245 2020-09-01      996.0         6.0    54395.0  2020      9    1        1
# 246 2020-09-02      975.0         8.0        NaN  2020      9    2        2
# 247 2020-09-03     1326.0         6.0        NaN  2020      9    3        3
#
#      total_cases  total_deaths  total_tests
# ...

# %%
result_df.to_csv('result.csv',index=None)

# %% [markdown]
# # Bonus:Basic Plotting with Pandas

# %%
import matplotlib as plot

# %%
result_df.new_cases.plot()
# Out:
# <Axes: >

# %%
result_df.new_deaths.plot()
# Out:
# <Axes: >

# %%
result_df.set_index('date',inplace=True)

# %%
result_df
# Out:
#             new_cases  new_deaths  new_tests  year  month  day  weekday
# date
# 2019-12-31        0.0         0.0        NaN  2019     12   31        1  \
# 2020-01-01        0.0         0.0        NaN  2020      1    1        2
# 2020-01-02        0.0         0.0        NaN  2020      1    2        3
# 2020-01-03        0.0         0.0        NaN  2020      1    3        4
# 2020-01-04        0.0         0.0        NaN  2020      1    4        5
# ...               ...         ...        ...   ...    ...  ...      ...
# 2020-08-30     1444.0         1.0    53541.0  2020      8   30        6
# 2020-08-31     1365.0         4.0    42583.0  2020      8   31        0
# 2020-09-01      996.0         6.0    54395.0  2020      9    1        1
# 2020-09-02      975.0         8.0        NaN  2020      9    2        2
# 2020-09-03     1326.0         6.0        NaN  2020      9    3        3
#
#             total_cases  total_deaths  total_tests
# date
# ...

# %%
result_df.loc['2020-09-01']
# Out:
# new_cases           996.0
# new_deaths            6.0
# new_tests         54395.0
# year               2020.0
# month                 9.0
# day                   1.0
# weekday               1.0
# total_cases      269619.0
# total_deaths      35483.0
# total_tests     4279456.0
# Name: 2020-09-01 00:00:00, dtype: float64

# %%
result_df.new_cases.plot()
result_df.new_deaths.plot()
# Out:
# <Axes: xlabel='date'>

# %%
result_df.new_cases.plot()
result_df.new_tests.plot();

# %%
death_rate=result_df.total_deaths / result_df.total_cases

# %%
death_rate.plot(title='Death Rate')
# Out:
# <Axes: title={'center': 'Death Rate'}, xlabel='date'>

# %%
_month_df.new_cases.plot(kind='bar')
# Out:
# <Axes: xlabel='month'>
