# %%
import pandas as pd

# %%
df= pd.read_excel(r"D:\New folder\Book1.xlsx")

# %%
df
# Out:
#     S.no       Dates        Day  Butter_Scotch  Rajbhog  Choco_chips
# 0       1 2023-05-01    Tuesday            265      346           216  \
# 1       2 2023-05-02  Wednesday            259      254           236
# 2       3 2023-05-03   Thursday            261      265           335
# 3       4 2023-05-04     Friday            295      235           356
# 4       5 2023-05-05   Saturday            254      356           326
# 5       6 2023-05-06     Sunday            250      389           356
# 6       7 2023-05-07     Monday            265      246           263
# 7       8 2023-05-08    Tuesday            246      235           345
# 8       9 2023-05-09  Wednesday            259      356           265
# 9      10 2023-05-10   Thursday            235      215           245
# 10     11 2023-05-11     Friday            244      356           279
# 11     12 2023-05-12   Saturday            264      354           238
# ...

# %% [markdown]
# # Data Preparation & cleaning

# %%
df.loc[22]
# Out:
# S.no                              23
# Dates            2023-05-23 00:00:00
# Day                        Wednesday
# Butter_Scotch                    269
# Rajbhog                          354
# Choco_chips                      345
# Friuts&Nuts                      258
# Amrican_Nuts                     345
# Tutty_Fruity                     690
# Name: 22, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   S.no           31 non-null     int64
#  1   Dates          31 non-null     datetime64[ns]
#  2   Day            31 non-null     object
#  3   Butter_Scotch  31 non-null     int64
#  4   Rajbhog        31 non-null     int64
#  5   Choco_chips    31 non-null     int64
#  6   Friuts&Nuts    31 non-null     int64
#  7   Amrican_Nuts   31 non-null     int64
#  8   Tutty_Fruity   31 non-null     int64
# dtypes: datetime64[ns](1), int64(7), object(1)
# memory usage: 2.3+ KB

# %%
df.shape
# Out:
# (31, 9)

# %%
df.columns
# Out:
# Index(['S.no ', 'Dates', 'Day', 'Butter_Scotch', 'Rajbhog', 'Choco_chips ',
#        'Friuts&Nuts', 'Amrican_Nuts', 'Tutty_Fruity'],
#       dtype='object')

# %%
df.describe()
# Out:
#            S.no                 Dates  Butter_Scotch     Rajbhog
# count  31.000000                   31      31.000000   31.000000  \
# mean   16.000000  2023-05-16 00:00:00     263.451613  306.290323
# min     1.000000  2023-05-01 00:00:00     223.000000  215.000000
# 25%     8.500000  2023-05-08 12:00:00     248.000000  254.000000
# 50%    16.000000  2023-05-16 00:00:00     261.000000  315.000000
# 75%    23.500000  2023-05-23 12:00:00     276.500000  356.000000
# max    31.000000  2023-05-31 00:00:00     300.000000  389.000000
# std     9.092121                  NaN      20.896313   55.604672
#
#        Choco_chips   Friuts&Nuts  Amrican_Nuts  Tutty_Fruity
# count     31.000000    31.000000     31.000000     31.000000
# mean     305.548387   318.161290    276.741935    582.290323
# min      216.000000   224.000000    100.000000    316.000000
# 25%      259.500000   261.500000    224.500000    518.500000
# 50%      326.000000   345.000000    288.000000    583.000000
# ...

# %%
df.sample(10)
# Out:
#     S.no       Dates        Day  Butter_Scotch  Rajbhog  Choco_chips
# 14     15 2023-05-15    Tuesday            275      351           349  \
# 22     23 2023-05-23  Wednesday            269      354           345
# 11     12 2023-05-12   Saturday            264      354           238
# 28     29 2023-05-29    Tuesday            246      356           365
# 3       4 2023-05-04     Friday            295      235           356
# 19     20 2023-05-20     Sunday            300      265           235
# 23     24 2023-05-24   Thursday            246      315           355
# 4       5 2023-05-05   Saturday            254      356           326
# 17     18 2023-05-18     Friday            262      254           235
# 30     31 2023-05-31   Thursday            267      356           315
#
#     Friuts&Nuts  Amrican_Nuts  Tutty_Fruity
# 14          352           265           614
# 22          258           345           690
# 11          236           296           534
# ...

# %%
df.head(10)
# Out:
#    S.no       Dates        Day  Butter_Scotch  Rajbhog  Choco_chips
# 0      1 2023-05-01    Tuesday            265      346           216  \
# 1      2 2023-05-02  Wednesday            259      254           236
# 2      3 2023-05-03   Thursday            261      265           335
# 3      4 2023-05-04     Friday            295      235           356
# 4      5 2023-05-05   Saturday            254      356           326
# 5      6 2023-05-06     Sunday            250      389           356
# 6      7 2023-05-07     Monday            265      246           263
# 7      8 2023-05-08    Tuesday            246      235           345
# 8      9 2023-05-09  Wednesday            259      356           265
# 9     10 2023-05-10   Thursday            235      215           245
#
#    Friuts&Nuts  Amrican_Nuts  Tutty_Fruity
# 0          224           100           316
# 1          244           123           359
# 2          343           134           469
# ...

# %%
df.fillna(0)
# Out:
#     S.no       Dates        Day  Butter_Scotch  Rajbhog  Choco_chips
# 0       1 2023-05-01    Tuesday            265      346           216  \
# 1       2 2023-05-02  Wednesday            259      254           236
# 2       3 2023-05-03   Thursday            261      265           335
# 3       4 2023-05-04     Friday            295      235           356
# 4       5 2023-05-05   Saturday            254      356           326
# 5       6 2023-05-06     Sunday            250      389           356
# 6       7 2023-05-07     Monday            265      246           263
# 7       8 2023-05-08    Tuesday            246      235           345
# 8       9 2023-05-09  Wednesday            259      356           265
# 9      10 2023-05-10   Thursday            235      215           245
# 10     11 2023-05-11     Friday            244      356           279
# 11     12 2023-05-12   Saturday            264      354           238
# ...

# %%
df['Dates'],['Rajbhog']
# Out:
# (0    2023-05-01
#  1    2023-05-02
#  2    2023-05-03
#  3    2023-05-04
#  4    2023-05-05
#  5    2023-05-06
#  6    2023-05-07
#  7    2023-05-08
#  8    2023-05-09
#  9    2023-05-10
#  10   2023-05-11
#  11   2023-05-12
#  12   2023-05-13
#  13   2023-05-14
#  14   2023-05-15
#  15   2023-05-16
#  16   2023-05-17
#  17   2023-05-18
#  18   2023-05-19
#  19   2023-05-20
#  20   2023-05-21
#  21   2023-05-22
#  22   2023-05-23
#  23   2023-05-24
#  24   2023-05-25
#  25   2023-05-26
#  26   2023-05-27
#  27   2023-05-28
#  28   2023-05-29
#  29   2023-05-30
#  30   2023-05-31
#  Name: Dates, dtype: datetime64[ns],
#  ['Rajbhog'])

# %% [markdown]
# # Exploratory Analysis & Visualization

# %%
df['Rajbhog'].sum()
# Out:
# 9495

# %%
df['Amrican Nuts'].sum()
# Out:
# 8579

# %%
df['Tutty Fruity'].sum()
# Out:
# 18051

# %%
df['Butter Scotch'].mean()
# Out:
# 263.4516129032258

# %%
df['Amrican Nuts'].mean()
# Out:
# 276.741935483871

# %%
df['Rajbhog'].mean()
# Out:
# 306.2903225806452

# %%
(df['Butter Scotch'].max()-df['Butter Scotch'].min())
# Out:
# 77

# %%
(df['Rajbhog'].max()-df['Rajbhog'].min())
# Out:
# 174

# %% [markdown]
# # Plotting Graph

# %%
import matplot as plot

# %%
df.plot(kind='line',x='Dates',y='Tutty Fruity',color='Blue')
# Out:
# <Axes: xlabel='Dates'>

# %%
df.plot(kind='scatter',x='Rajbhog',y='Dates',color='Red')
# Out:
# <Axes: xlabel='Rajbhog', ylabel='Dates'>

# %%
df.plot(kind='line', x='Tutty Fruity',y='Dates',color='Black')
# Out:
# <Axes: xlabel='Tutty Fruity'>

# %% [markdown]
# # Analysing Data

# %% [markdown]
# Q1 What is the total sales of (Tutty fruity )in this month?

# %%
df['Tutty Fruity'].sum()
# Out:
# 18051

# %% [markdown]
# Q2 Find the lowest Quentity sales of Rajbhog ?

# %%
df['Rajbhog'].min()
# Out:
# 215

# %% [markdown]
# Q3 Find the Highest Quentity sales of Rajbhog ?

# %%
df['Rajbhog'].max()
# Out:
# 389

# %% [markdown]
# Q4 Find out the highest sales of Tutty fruity With date & day?

# %%
df2=df[['Dates','Day','Tutty Fruity']].max()

# %%
df2
# Out:
# Dates           2023-05-31 00:00:00
# Day                       Wednesday
# Tutty Fruity                    750
# dtype: object
